# %%
# %matplotlib inline

# %%
# data from https://fantasy.premierleague.com/drf/bootstrap-static

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import urllib.request 

# extracting data from site
fpl_data = urllib.request.urlopen('https://fantasy.premierleague.com/drf/bootstrap-static').read()
fpl_data = json.loads(fpl_data)

# %%
# columns for the data frame (positions)
columns = []
for i in range(4):
    columns.append(fpl_data['element_types'][i]['plural_name'])

# %%
# list of elements
players = fpl_data['elements']

# %%
# making teams list 
teams = []
for i in range(1, 21):
    temp_list = []
    for player in players:
        if player['team'] == i:
            temp_list.append(player)
    teams.append(temp_list)
num_of_players = [len(x) for x in teams]

# %%
# cumulative prices
prices = []
for team in teams:
    price = 0
    for player in team:
        price += player['now_cost'] - player['cost_change_start']
    prices.append(float(price / 10))
    
team_names = [x['name'] for x in fpl_data['teams']]

# %%
data = pd.DataFrame()
data['Team'] = team_names
data['Players'] = num_of_players
data['Total Cost'] = prices
data['Average Cost'] = data['Total Cost'] / data['Players']
data
# Out:
#               Team  Players  Total Cost  Average Cost
# 0          Arsenal       30       186.5      6.216667
# 1      Bournemouth       24       124.0      5.166667
# 2         Brighton       24       114.5      4.770833
# 3          Burnley       21       102.0      4.857143
# 4          Chelsea       24       155.5      6.479167
# 5   Crystal Palace       26       130.5      5.019231
# 6          Everton       28       157.5      5.625000
# 7     Huddersfield       28       133.5      4.767857
# 8        Leicester       27       144.5      5.351852
# 9        Liverpool       29       171.0      5.896552
# 10        Man City       25       164.0      6.560000
# 11         Man Utd       27       159.0      5.888889
# 12       Newcastle       28       134.0      4.785714
# 13     Southampton       25       129.5      5.180000
# 14           Stoke       24       122.0      5.083333
# 15         Swansea       25       121.0      4.840000
# 16           Spurs       22       138.0      6.272727
# 17         Watford       29       144.5      4.982759
# 18       West Brom       22       110.0      5.000000
# 19        West Ham       27       143.5      5.314815

# %%
plt.style.use('dark_background')
plt.plot(data['Average Cost'], '-o', color='white')
plt.xticks(list(range(20)), team_names, rotation=45)
ax.tick_params(axis='x', which='major', pad=15)
plt.xlabel('Club')
plt.ylabel('Average Fantasy Price')
plt.title('Average Fantasy Premier League Price for Each Club')
